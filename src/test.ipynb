# %%
import pandas as pd

df = pd.read_csv(r"D:\Python Course\Sentiment Analysis on Twitter Project\data\raw\1.6M-Tweets.csv", encoding="utf-8", encoding_errors="ignore")
df.shape
# Out:
# (1599999, 6)
